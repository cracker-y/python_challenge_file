# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
# 갑자기 생각나서 이름을 한번 줄여봤습니다.
# 모듈파일은 구글 드라이브에서 불러왔습니다.
import myMath as my

print(f'삼각형 넓이: {my.getTriangle(3,4)}')
print(f'원의 넓이: {my.getCircle(5)}')
print(f'직육면체의 넓이: {my.getRectangular(3,4,5)}')
# Out:
# 삼각형 넓이: 6
# 원의 넓이: 78.540
# 직육면체의 넓이: 60

# %%
# 밑에 사진은 모듈 내부구조입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
